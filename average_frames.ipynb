# %%
from torchvision import models
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from random import shuffle
import numpy as np
import os
from PIL import Image
from torchvision import transforms
import random
import torch

# %%
test_transform = transforms.Compose(
    [transforms.Resize(256),  # 1. Resize smallest side to 256.
     transforms.CenterCrop(224), # 2. Crop center square of 224x224 pixels.
     transforms.ToTensor(), # 3. Convert to pytorch tensor.
     transforms.Normalize(mean = [0.485, 0.456, 0.406],  # normalize.
                          std = [0.229, 0.224, 0.225])
    ])

# %%
def get_img_list(cat,d1):
    ret = list()
    for frame in os.listdir('data/data_first_25/{}/{}'.format(cat,d1)):
        img_pil = Image.open('data/data_first_25/{}/{}/{}'.format(cat,d1,frame))
        input_img = test_transform(img_pil).unsqueeze(0)
        ret.append(input_img)
    return ret

def createTrainAndValSet(categories,trainPercentage):
    category_options = os.listdir('data/data_first_25')
    category_names = category_options[:categories]
    train_set = []
    val_set = []
    i=0
    for cat in category_names:
        for d1 in os.listdir('data/data_first_25/{}'.format(cat)):
            r = random.uniform(0,1)
            img_list = get_img_list(cat,d1)
            if r < trainPercentage:
                train_set.append((img_list,i))
            else:
                val_set.append((img_list,i))
        i+=1
    return train_set,val_set

# %%
class AverageModel(nn.Module):
    def __init__(self, output_size=5):
        super(AverageModel, self).__init__()

        resnet = models.resnet18(pretrained=True)
        modules = list(resnet.children())[:-1]      # delete the last fc layer.
        self.output_size = output_size
        self.resnet = nn.Sequential(*modules)
        self.fc1 = nn.Linear(resnet.fc.in_features, output_size)
        
    def forward(self, x_3d):
        result = torch.zeros((1,self.output_size)).cuda()
        for t in range(x_3d.size(1)):
            with torch.no_grad():
                x = self.resnet(x_3d[:, t, :, :, :])  # ResNet
                x = x.view(x.size(0), -1)             # flatten output of conv

            # FC layers
            x = self.fc1(x)
          
            result += x
        result /= x_3d.size(1)

        return result

# %%
train_accuracies = []; train_losses = [];
val_accuracies = []; val_losses = [];

def train_model(model, loss_fn, optimizer, epochs):
    model = model.cuda()
    loss_fn = loss_fn.cuda()
    batchSize = 1

    for epoch in range(epochs):
        correct = 0
        cum_loss = 0

        i = 0
        model.train()
        for video in train_set:
            frame_list, target_cat = video
            frame_list = torch.stack(frame_list, dim=0).transpose(0, 1).cuda()
            scores = model(frame_list)
            
            loss = loss_fn(scores, torch.tensor(np.array([target_cat]),dtype=torch.long).cuda())
            max_score, max_label = scores.max(1)
            if max_label == target_cat:
                correct+=1
            cum_loss += loss.item()
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if (i + 1) % 100 == 0:
                print('Train-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
                    (epoch, i + 1, cum_loss / (i + 1), correct / ((i + 1) * batchSize)))
            i += 1
            
        train_accuracies.append(correct / len(train_set))
        train_losses.append(cum_loss / (i + 1))   
        
        i = 0
        correct = 0
        cum_loss = 0
        model.eval()
        for video in val_set:
            frame_list, target_cat = video
            frame_list = torch.stack(frame_list, dim=0).transpose(0, 1).cuda()
            scores = model(frame_list)
            
            loss = loss_fn(scores, torch.tensor(np.array([target_cat]),dtype=torch.long).cuda())
            max_score, max_label = scores.max(1)
            if max_label == target_cat:
                correct+=1
            cum_loss += loss.item()
            
            i += 1
        print('Validation-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
               (epoch, i + 1, cum_loss / (i + 1), correct / len(val_set)))
        
        val_accuracies.append(correct / len(val_set))
        val_losses.append(cum_loss / (i + 1))

# %%
categories = 15

train_set, val_set = createTrainAndValSet(categories, 0.8)

# %%
learning_rate = 1e-3

my_model = AverageModel(output_size=categories)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(my_model.fc1.parameters(), lr=learning_rate)
epochs = 10

train_model(my_model, loss_fn, optimizer, epochs)
# Out:
# Train-epoch 0. Iteration 00100, Avg-Loss: 0.8037, Accuracy: 0.8800
# Train-epoch 0. Iteration 00200, Avg-Loss: 0.9199, Accuracy: 0.8900
# Train-epoch 0. Iteration 00300, Avg-Loss: 0.6133, Accuracy: 0.9267
# Train-epoch 0. Iteration 00400, Avg-Loss: 0.8501, Accuracy: 0.9175
# Train-epoch 0. Iteration 00500, Avg-Loss: 1.1327, Accuracy: 0.9100
# Train-epoch 0. Iteration 00600, Avg-Loss: 1.4408, Accuracy: 0.9017
# Train-epoch 0. Iteration 00700, Avg-Loss: 1.7364, Accuracy: 0.8957
# Train-epoch 0. Iteration 00800, Avg-Loss: 2.0472, Accuracy: 0.8900
# Train-epoch 0. Iteration 00900, Avg-Loss: 2.3358, Accuracy: 0.8844
# Train-epoch 0. Iteration 01000, Avg-Loss: 2.6037, Accuracy: 0.8800
# Train-epoch 0. Iteration 01100, Avg-Loss: 2.8562, Accuracy: 0.8764
# Train-epoch 0. Iteration 01200, Avg-Loss: 3.1119, Accuracy: 0.8725
# Train-epoch 0. Iteration 01300, Avg-Loss: 3.3137, Accuracy: 0.8723
# Train-epoch 0. Iteration 01400, Avg-Loss: 3.3500, Accuracy: 0.8743
# Train-epoch 0. Iteration 01500, Avg-Loss: 3.3086, Accuracy: 0.8753
# Train-epoch 0. Iteration 01600, Avg-Loss: 3.5207, Accuracy: 0.8725
# Validation-epoch 0. Iteration 00418, Avg-Loss: 63.6901, Accuracy: 0.0504
# Train-epoch 1. Iteration 00100, Avg-Loss: 14.0628, Accuracy: 0.6700
# Train-epoch 1. Iteration 00200, Avg-Loss: 10.3852, Accuracy: 0.7350
# Train-epoch 1. Iteration 00300, Avg-Loss: 6.9474, Accuracy: 0.8167
# Train-epoch 1. Iteration 00400, Avg-Loss: 6.6444, Accuracy: 0.8200
# Train-epoch 1. Iteration 00500, Avg-Loss: 6.3922, Accuracy: 0.8240
# Train-epoch 1. Iteration 00600, Avg-Loss: 6.1931, Accuracy: 0.8267
# Train-epoch 1. Iteration 00700, Avg-Loss: 6.0486, Accuracy: 0.8286
# Train-epoch 1. Iteration 00800, Avg-Loss: 5.9237, Accuracy: 0.8300
# Train-epoch 1. Iteration 00900, Avg-Loss: 5.8276, Accuracy: 0.8311
# Train-epoch 1. Iteration 01000, Avg-Loss: 5.7462, Accuracy: 0.8320
# Train-epoch 1. Iteration 01100, Avg-Loss: 5.7006, Accuracy: 0.8327
# Train-epoch 1. Iteration 01200, Avg-Loss: 5.6682, Accuracy: 0.8333
# Train-epoch 1. Iteration 01300, Avg-Loss: 5.6184, Accuracy: 0.8362
# Train-epoch 1. Iteration 01400, Avg-Loss: 5.4507, Accuracy: 0.8414
# Train-epoch 1. Iteration 01500, Avg-Loss: 5.2469, Accuracy: 0.8447
# Train-epoch 1. Iteration 01600, Avg-Loss: 5.2996, Accuracy: 0.8438
# Validation-epoch 1. Iteration 00418, Avg-Loss: 57.5295, Accuracy: 0.0504
# Train-epoch 2. Iteration 00100, Avg-Loss: 11.6797, Accuracy: 0.6900
# Train-epoch 2. Iteration 00200, Avg-Loss: 8.8506, Accuracy: 0.7500
# Train-epoch 2. Iteration 00300, Avg-Loss: 5.9109, Accuracy: 0.8300
# Train-epoch 2. Iteration 00400, Avg-Loss: 5.7976, Accuracy: 0.8300
# Train-epoch 2. Iteration 00500, Avg-Loss: 5.6951, Accuracy: 0.8320
# Train-epoch 2. Iteration 00600, Avg-Loss: 5.6279, Accuracy: 0.8333
# Train-epoch 2. Iteration 00700, Avg-Loss: 5.5683, Accuracy: 0.8343
# Train-epoch 2. Iteration 00800, Avg-Loss: 5.5065, Accuracy: 0.8350
# Train-epoch 2. Iteration 00900, Avg-Loss: 5.4589, Accuracy: 0.8356
# Train-epoch 2. Iteration 01000, Avg-Loss: 5.4222, Accuracy: 0.8360
# Train-epoch 2. Iteration 01100, Avg-Loss: 5.4021, Accuracy: 0.8364
# Train-epoch 2. Iteration 01200, Avg-Loss: 5.3875, Accuracy: 0.8367
# Train-epoch 2. Iteration 01300, Avg-Loss: 5.3616, Accuracy: 0.8392
# Train-epoch 2. Iteration 01400, Avg-Loss: 5.2174, Accuracy: 0.8443
# Train-epoch 2. Iteration 01500, Avg-Loss: 5.0391, Accuracy: 0.8473
# Train-epoch 2. Iteration 01600, Avg-Loss: 5.0827, Accuracy: 0.8462
# Validation-epoch 2. Iteration 00418, Avg-Loss: 56.6919, Accuracy: 0.0504
# Train-epoch 3. Iteration 00100, Avg-Loss: 11.2837, Accuracy: 0.6900
# Train-epoch 3. Iteration 00200, Avg-Loss: 8.5855, Accuracy: 0.7500
# Train-epoch 3. Iteration 00300, Avg-Loss: 5.7317, Accuracy: 0.8300
# Train-epoch 3. Iteration 00400, Avg-Loss: 5.6559, Accuracy: 0.8300
# Train-epoch 3. Iteration 00500, Avg-Loss: 5.5991, Accuracy: 0.8320
# Train-epoch 3. Iteration 00600, Avg-Loss: 5.5584, Accuracy: 0.8333
# Train-epoch 3. Iteration 00700, Avg-Loss: 5.5178, Accuracy: 0.8343
# Train-epoch 3. Iteration 00800, Avg-Loss: 5.4694, Accuracy: 0.8350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-84f43eb7f00b> in <module>()
#       7 epochs = 10
#       8
# ----> 9 train_model(my_model, loss_fn, optimizer, epochs)
#
# <ipython-input-32-03c04dfee962> in train_model(model, loss_fn, optimizer, epochs)
#      16             frame_list, target_cat = video
#      17             frame_list = torch.stack(frame_list, dim=0).transpose(0, 1).cuda()
# ---> 18             scores = model(frame_list)
#      19
#      20             loss = loss_fn(scores, torch.tensor(np.array([target_cat]),dtype=torch.long).cuda())
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-24-453719ea8757> in forward(self, x_3d)
#      13         for t in range(x_3d.size(1)):
#      14             with torch.no_grad():
# ---> 15                 x = self.resnet(x_3d[:, t, :, :, :])  # ResNet
#      16                 x = x.view(x.size(0), -1)             # flatten output of conv
#      17
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      39         residual = x
#      40
# ---> 41         out = self.conv1(x)
#      42         out = self.bn1(out)
#      43         out = self.relu(out)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:
